# %%
import pandas as pd

# %%
data_train=pd.read_csv('drugsComTrain_raw.csv')
data_train
# Out:
#                                           drugName  \
# 0                                      Ogestrel-28
# 1                                         Implanon
# 2                                         Implanon
# 3                                        Hypercare
# 4                                        Hypercare
# ...                                            ...
# 161292            Ethinyl estradiol / norgestimate
# 161293            Drospirenone / ethinyl estradiol
# 161294                                  Pregabalin
# 161295  Polyethylene glycol 3350 with electrolytes
# 161296          Ethinyl estradiol / levonorgestrel
#
#                                          condition  \
# 0       0</span> users found this comment helpful.
# 1       0</span> users found this comment helpful.
# 2       0</span> users found this comment helpful.
# 3       0</span> users found this comment helpful.
# 4       0</span> users found this comment helpful.
# ...

# %%
data_train.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DA513C7E88>,
# ...
#       dtype=object)

# %%
data_train['condition'].unique()
# Out:
# array(['0</span> users found this comment helpful.',
#        '1</span> users found this comment helpful.',
#        '10</span> users found this comment helpful.',
#        '11</span> users found this comment helpful.',
#        '110</span> users found this comment helpful.',
#        '12</span> users found this comment helpful.',
#        '121</span> users found this comment helpful.',
#        '123</span> users found this comment helpful.',
#        '13</span> users found this comment helpful.',
#        '14</span> users found this comment helpful.',
#        '142</span> users found this comment helpful.',
#        '145</span> users found this comment helpful.',
#        '146</span> users found this comment helpful.',
#        '15</span> users found this comment helpful.',
#        '16</span> users found this comment helpful.',
#        '17</span> users found this comment helpful.',
#        '18</span> users found this comment helpful.',
# ...

# %%
patternDel = "span"
# Out:
#   File "<ipython-input-50-f89cdd756843>", line 2
#     data_train['condition'].str.contains(patternDel).map(lambda: if(type(x)==bool)) return True else return False)
#                                                                   ^
# SyntaxError: invalid syntax

# %%
to_remove
